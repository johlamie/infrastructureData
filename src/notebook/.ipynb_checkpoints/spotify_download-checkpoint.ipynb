# %%
#!pip install spotipy

# %%
import spotipy
import json

# %%
#définition des variables utilisateur:
CLIENT_ID="7a37fb7eb8a7444294491f8dd4488c83"
CLIENT_SECRET="d75fb92060b6440b8f29f26f00c0310a"

# %%
#Connection:
from spotipy.oauth2 import SpotifyClientCredentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,client_secret=CLIENT_SECRET))

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
release_date= []

for i in range(0,2000,50):
    track_results = sp.search(q='year:2020', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        release_date.append(t['album']['release_date'])

# %%
import pandas as pd

df_tracks = pd.DataFrame({'artist_name':artist_name,'track_name':track_name,'track_id':track_id,'popularity':popularity,'date':release_date})
print(df_tracks.shape)
# check if everything is ok
#df_tracks.head()
# Out:
# (2000, 5)

# %%
# df_tracks.sort_values(by='date', ascending=False).head(10)

# %%
# df_tracks.sort_values(by='popularity', ascending=False)

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
release_date= []

for i in range(0,1000):
    track_results = sp.search(q='year:2019')
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])

# %%
import pandas as pd

df_tracks = pd.DataFrame({'artist_name':artist_name,'track_name':track_name,'track_id':track_id,'popularity':popularity})
print(df_tracks.shape)
# check if everything is ok
# df_tracks.head()
# Out:
# (10000, 4)

# %%
df_tracks.drop_duplicates()
# print(df_tracks.shape)
# Out:
#       artist_name                                      track_name  \
# 0     Roddy Ricch                                         The Box
# 1          Clairo                                           Sofia
# 2      Juice WRLD                                         Robbery
# 3    Harry Styles                                Watermelon Sugar
# 4     Post Malone                                         Circles
# 5         Wallows               Are You Bored Yet? (feat. Clairo)
# 6   Lewis Capaldi                               Someone You Loved
# 7    Travis Scott                             HIGHEST IN THE ROOM
# 8      Juice WRLD        Bandit (with YoungBoy Never Broke Again)
# 9         JP Saxe  If the World Was Ending - feat. Julia Michaels
# 19       Lil Peep                                   Star Shopping
#
#                   track_id  popularity
# 0   0nbXyq5TXYPCO7pr3N8S4I          89
# 1   7B3z0ySL9Rr0XvZEAjWZzM          90
# 2   6Hj9jySrnFppAI0sEMCZpJ          89
# 3   6UelLqGlWMcVH1E5c4H7lY          93
# 4   21jGcNKet2qwijlDFuPiPb          90
# 5   57RA3JGafJm5zRtKJiKPIm          86
# 6   7qEHsqek33rTcFNT9PFqLf          91
# 7   3eekarcy7kvN4yt5ZFzltW          88
# 8   6Gg1gjgKi2AK4e0qzsR7sd          84
# 9   2kJwzbxV2ppxnQoYw4GLBZ          87
# 19  30bqVoKjX479ab90a8Pafp          86

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
release_date= []

for i in range(0,1):
    track_results = sp.search(q='year:2019')

# %%
track_results = sp.search(q='year:2020')

# %%
from datetime import date

today = date.today().strftime("%Y-%m-%d")

file = 'data/{}.json'.format(today)

with open(file, "w") as f:
    json.dump(track_results, f, sort_keys=True)
    f.write('\n')
    
f.close()

# %%
#--------------------------------------------------------------------------#

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
release_date= []

for i in range(0,10):
    track_results = sp.search(q='year:2020', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        release_date.append(t['album']['release_date'])

# %%
import pandas as pd

df_tracks = pd.DataFrame({'artist_name':artist_name,'track_name':track_name,'track_id':track_id,'popularity':popularity})
# check if everything is ok
# df_tracks.head()

# %%
len(df_tracks['track_name'].unique())
# Out:
# 60

# %%
df_tracks.drop_duplicates()
# Out:
#              artist_name                                         track_name  \
# 0               24kGoldn                             Mood (feat. iann dior)
# 1          Ariana Grande                                          positions
# 2              Pop Smoke            For The Night (feat. Lil Baby & DaBaby)
# 3              Bad Bunny                                             Dakiti
# 4                Cardi B                    WAP (feat. Megan Thee Stallion)
# 5          Ariana Grande                                              34+35
# 6                  Drake               Laugh Now Cry Later (feat. Lil Durk)
# 7          Billie Eilish                                     Therefore I Am
# 8              Pop Smoke                            What You Know Bout Love
# 9             The Weeknd                                    Blinding Lights
# 10        Internet Money                                           Lemonade
# 11                DaBaby                       ROCKSTAR (feat. Roddy Ricch)
# 12            Juice WRLD                                       Wishing Well
# 13            Conan Gray                                            Heather
# 14         Justin Bieber                     Holy (feat. Chance The Rapper)
# 15                   BTS                                       Life Goes On
# 16         Justin Bieber                         Lonely (with benny blanco)
# 17           Jack Harlow                                        Tyler Herro
# 18             Lil Nas X                                            HOLIDAY
# 19           Ritt Momney                                Put Your Records On
# 20            Juice WRLD                        Come & Go (with Marshmello)
# 21            Tate McRae                                 you broke me first
# 22         Ariana Grande                                                pov
# 23            Luke Combs                                  Forever After All
# 24                Polo G                                      Martin & Gina
# 25             21 Savage                                             Runnin
# 26   Megan Thee Stallion                                               Body
# 27                    CJ                                            Whoopty
# 28     Machine Gun Kelly               my ex's best friend (with blackbear)
# 29             DJ Khaled                              POPSTAR (feat. Drake)
# 30             21 Savage                        Mr. Right Now (feat. Drake)
# 31          Shawn Mendes                                             Wonder
# 32                   BTS                                           Dynamite
# 33                DaBaby                                           PRACTICE
# 34        Internet Money          Lemonade (feat. Gunna, Don Toliver & NAV)
# 35              Dua Lipa                          Levitating (feat. DaBaby)
# 36             Bad Bunny                                 LA NOCHE DE ANOCHE
# 37             Pop Smoke                       Mood Swings (feat. Lil Tjay)
# 38            Juice WRLD                      Real Shit (with benny blanco)
# 39              Ashnikko                                              Daisy
# 40            Kane Brown             Be Like That - feat. Swae Lee & Khalid
# 41         Morgan Wallen                                          7 Summers
# 42                Maluma                                      Hawái - Remix
# 43                CORPSE                       E-GIRLS ARE RUINING MY LIFE!
# 44         The Kid LAROI                                        WITHOUT YOU
# 45             Bad Bunny                                         TE MUDASTE
# 46                 Powfu                   death bed (coffee for your head)
# 47           Chris Brown                                           Go Crazy
# 48         The Kid LAROI                              GO (feat. Juice WRLD)
# 49         Morgan Wallen                              More Than My Hometown
# 76          Shawn Mendes             Monster (Shawn Mendes & Justin Bieber)
# 149        The Kid LAROI                                            SO DONE
# 199           Juice WRLD                                          Righteous
# 247          Don Toliver                                        After Party
# 249        Morgan Wallen                                 Somebody’s Problem
# 299        Ariana Grande                             motive (with Doja Cat)
# 349            Pop Smoke               Hello (feat. A Boogie Wit da Hoodie)
# 399           Juice WRLD  Hate The Other Side (with Marshmello & The Kid...
# 449            Bad Bunny                                       YO VISTO ASÍ
# 499            blackbear                                    hot girl bummer
#
#                    track_id  popularity
# 0    3tjFYV6RSFtuktYl3ZtYcq          99
# 1    35mvY5S1H3J2QZyna3TFe0          97
# 2    0PvFJmanyNQMseIFrU708S          94
# 3    47EiUVwUp4C9fGccaPuUCS         100
# 4    4Oun2ylbjFKMPTiaSbbCih          95
# 5    6Im9k8u9iIzKMrmV7BWtlF          94
# 6    2SAqBLGA283SUiwJ3xOUVI          92
# 7    54bFM56PmE4YLRnqpW6Tha          96
# 8    1tkg4EHVoqnhR6iFEXb60y          95
# 9    0VjIjW4GlUZAMYd2vXMi3b          97
# 10   02kDW379Yfd5PzW5A6vuGt          93
# 11   7ytR5pFWmSjzHJIeQkgog4          93
# 12   2U5WueTLIK5WJLD7mvDODv          90
# 13   4xqrdfXkTW4T0RauPLv3WA          93
# 14   5u1n1kITHCxxp8twBcZxWy          94
# 15   249gnXrbfmV8NG6jTEMSwD          95
# 16   4y4spB9m0Q6026KfkAvy9Q          95
# 17   4DuUwzP4ALMqpquHU0ltAB          88
# 18   6zFMeegAMYQo0mt8rXtrli          91
# 19   6AGOKlMZWLCaEJGnaROtF9          92
# 20   2Y0wPrPQBrGhoLn14xRYCG          89
# 21   45bE4HXI0AwGZXfZtMp8JR          94
# 22   3UoULw70kMsiVXxW0L3A33          90
# 23   6IBcOGPsniK3Pso1wHIhew          85
# 24   1VLtjHwRWOVJiE5Py7JxoQ          87
# 25   5SWnsxjhdcEDc7LJjq9UHk          86
# 26   0A1hoCfMLkiAgvhWkkucJa          86
# 27   5vGLcdRuSbUhD8ScwsGSdA          91
# 28   7kDUspsoYfLkWnZR7qwHZl          88
# 29   6EDO9iiTtwNv6waLwa1UUq          89
# 30   4Q34FP1AT7GEl9oLgNtiWj          85
# 31   5KCbr5ndeby4y4ggthdiAb          92
# 32   0t1kP63rueHleOhQkYSXFY          94
# 33   4Z5FyQlevoHoa5FsIVKZju          84
# 34   7hxHWCCAIIxFLCzvDgnQHX          90
# 35   463CkQjx2Zk1yXoBuierM9          90
# 36   2XIc1pqjXV3Cr2BQUGNBck          93
# 37   5rZlwNFl01HqLWBQGryKSm          89
# 38   3uVPLtkmDu8pDkYEAVqbgS          83
# 39   0AUvWawuP0ibk4SQ3sIZjk          89
# 40   5f1joOtoMeyppIcJGZQvqJ          85
# 41   0tbjiOUl4k492KPdWZS9sy          82
# 42   0GzuHFG4Ql6DoyxFRnIk3F          90
# 43   7bCfHiRcfUjG0YVVNUL7Ve          86
# 44   27OeeYzk6klgBh83TSvGMA          87
# 45   5RubKOuDoPn5Kj5TLVxSxY          90
# 46   7eJMfftS33KTjuF7lTsMCx          90
# 47   1IIKrJVP1C9N7iPtG6eOsK          88
# 48   2rPHUAeUPbNgTmK18FPTiZ          83
# 49   0eBXyY4SatzpE7opnzgXvz          81
# 76   2Z8yfpFX0ZMavHkcIeHiO1          93
# 149  5psEZhQu6lukjhavJo4AbC          87
# 199  5dOxHHMOFAbG3VH23t0xNm          84
# 247  527k23H0A4Q0UJN3vGs0Da          85
# 249  0SErdEdRcVX1uJCf1eTGYH          81
# 299  5GkQIP5mWPi4KZLLXeuFTT          86
# 349  2r6OAV3WsYtXuXjvJ1lIDi          87
# 399  0ada5XsQGLPUVbmTCkAP49          84
# 449  5fROvzNghPid8mbKNDYvpJ          88
# 499  2mt1IqcFyY1zmYZT8Q3xw9          86

# %%
len(df_tracks.drop_duplicates())
df_tracks=df_tracks.drop_duplicates()

# %%
df_tracks.sort_values(by='popularity', ascending=False)
# Out:
#              artist_name                                         track_name  \
# 3              Bad Bunny                                             Dakiti
# 0               24kGoldn                             Mood (feat. iann dior)
# 1          Ariana Grande                                          positions
# 9             The Weeknd                                    Blinding Lights
# 7          Billie Eilish                                     Therefore I Am
# 4                Cardi B                    WAP (feat. Megan Thee Stallion)
# 16         Justin Bieber                         Lonely (with benny blanco)
# 8              Pop Smoke                            What You Know Bout Love
# 15                   BTS                                       Life Goes On
# 32                   BTS                                           Dynamite
# 21            Tate McRae                                 you broke me first
# 14         Justin Bieber                     Holy (feat. Chance The Rapper)
# 5          Ariana Grande                                              34+35
# 2              Pop Smoke            For The Night (feat. Lil Baby & DaBaby)
# 13            Conan Gray                                            Heather
# 11                DaBaby                       ROCKSTAR (feat. Roddy Ricch)
# 10        Internet Money                                           Lemonade
# 76          Shawn Mendes             Monster (Shawn Mendes & Justin Bieber)
# 36             Bad Bunny                                 LA NOCHE DE ANOCHE
# 6                  Drake               Laugh Now Cry Later (feat. Lil Durk)
# 19           Ritt Momney                                Put Your Records On
# 31          Shawn Mendes                                             Wonder
# 18             Lil Nas X                                            HOLIDAY
# 27                    CJ                                            Whoopty
# 42                Maluma                                      Hawái - Remix
# 46                 Powfu                   death bed (coffee for your head)
# 35              Dua Lipa                          Levitating (feat. DaBaby)
# 34        Internet Money          Lemonade (feat. Gunna, Don Toliver & NAV)
# 22         Ariana Grande                                                pov
# 12            Juice WRLD                                       Wishing Well
# 45             Bad Bunny                                         TE MUDASTE
# 29             DJ Khaled                              POPSTAR (feat. Drake)
# 37             Pop Smoke                       Mood Swings (feat. Lil Tjay)
# 20            Juice WRLD                        Come & Go (with Marshmello)
# 39              Ashnikko                                              Daisy
# 28     Machine Gun Kelly               my ex's best friend (with blackbear)
# 449            Bad Bunny                                       YO VISTO ASÍ
# 47           Chris Brown                                           Go Crazy
# 17           Jack Harlow                                        Tyler Herro
# 349            Pop Smoke               Hello (feat. A Boogie Wit da Hoodie)
# 149        The Kid LAROI                                            SO DONE
# 24                Polo G                                      Martin & Gina
# 44         The Kid LAROI                                        WITHOUT YOU
# 299        Ariana Grande                             motive (with Doja Cat)
# 499            blackbear                                    hot girl bummer
# 43                CORPSE                       E-GIRLS ARE RUINING MY LIFE!
# 26   Megan Thee Stallion                                               Body
# 25             21 Savage                                             Runnin
# 40            Kane Brown             Be Like That - feat. Swae Lee & Khalid
# 247          Don Toliver                                        After Party
# 23            Luke Combs                                  Forever After All
# 30             21 Savage                        Mr. Right Now (feat. Drake)
# 33                DaBaby                                           PRACTICE
# 199           Juice WRLD                                          Righteous
# 399           Juice WRLD  Hate The Other Side (with Marshmello & The Kid...
# 48         The Kid LAROI                              GO (feat. Juice WRLD)
# 38            Juice WRLD                      Real Shit (with benny blanco)
# 41         Morgan Wallen                                          7 Summers
# 49         Morgan Wallen                              More Than My Hometown
# 249        Morgan Wallen                                 Somebody’s Problem
#
#                    track_id  popularity
# 3    47EiUVwUp4C9fGccaPuUCS         100
# 0    3tjFYV6RSFtuktYl3ZtYcq          99
# 1    35mvY5S1H3J2QZyna3TFe0          97
# 9    0VjIjW4GlUZAMYd2vXMi3b          97
# 7    54bFM56PmE4YLRnqpW6Tha          96
# 4    4Oun2ylbjFKMPTiaSbbCih          95
# 16   4y4spB9m0Q6026KfkAvy9Q          95
# 8    1tkg4EHVoqnhR6iFEXb60y          95
# 15   249gnXrbfmV8NG6jTEMSwD          95
# 32   0t1kP63rueHleOhQkYSXFY          94
# 21   45bE4HXI0AwGZXfZtMp8JR          94
# 14   5u1n1kITHCxxp8twBcZxWy          94
# 5    6Im9k8u9iIzKMrmV7BWtlF          94
# 2    0PvFJmanyNQMseIFrU708S          94
# 13   4xqrdfXkTW4T0RauPLv3WA          93
# 11   7ytR5pFWmSjzHJIeQkgog4          93
# 10   02kDW379Yfd5PzW5A6vuGt          93
# 76   2Z8yfpFX0ZMavHkcIeHiO1          93
# 36   2XIc1pqjXV3Cr2BQUGNBck          93
# 6    2SAqBLGA283SUiwJ3xOUVI          92
# 19   6AGOKlMZWLCaEJGnaROtF9          92
# 31   5KCbr5ndeby4y4ggthdiAb          92
# 18   6zFMeegAMYQo0mt8rXtrli          91
# 27   5vGLcdRuSbUhD8ScwsGSdA          91
# 42   0GzuHFG4Ql6DoyxFRnIk3F          90
# 46   7eJMfftS33KTjuF7lTsMCx          90
# 35   463CkQjx2Zk1yXoBuierM9          90
# 34   7hxHWCCAIIxFLCzvDgnQHX          90
# 22   3UoULw70kMsiVXxW0L3A33          90
# 12   2U5WueTLIK5WJLD7mvDODv          90
# 45   5RubKOuDoPn5Kj5TLVxSxY          90
# 29   6EDO9iiTtwNv6waLwa1UUq          89
# 37   5rZlwNFl01HqLWBQGryKSm          89
# 20   2Y0wPrPQBrGhoLn14xRYCG          89
# 39   0AUvWawuP0ibk4SQ3sIZjk          89
# 28   7kDUspsoYfLkWnZR7qwHZl          88
# 449  5fROvzNghPid8mbKNDYvpJ          88
# 47   1IIKrJVP1C9N7iPtG6eOsK          88
# 17   4DuUwzP4ALMqpquHU0ltAB          88
# 349  2r6OAV3WsYtXuXjvJ1lIDi          87
# 149  5psEZhQu6lukjhavJo4AbC          87
# 24   1VLtjHwRWOVJiE5Py7JxoQ          87
# 44   27OeeYzk6klgBh83TSvGMA          87
# 299  5GkQIP5mWPi4KZLLXeuFTT          86
# 499  2mt1IqcFyY1zmYZT8Q3xw9          86
# 43   7bCfHiRcfUjG0YVVNUL7Ve          86
# 26   0A1hoCfMLkiAgvhWkkucJa          86
# 25   5SWnsxjhdcEDc7LJjq9UHk          86
# 40   5f1joOtoMeyppIcJGZQvqJ          85
# 247  527k23H0A4Q0UJN3vGs0Da          85
# 23   6IBcOGPsniK3Pso1wHIhew          85
# 30   4Q34FP1AT7GEl9oLgNtiWj          85
# 33   4Z5FyQlevoHoa5FsIVKZju          84
# 199  5dOxHHMOFAbG3VH23t0xNm          84
# 399  0ada5XsQGLPUVbmTCkAP49          84
# 48   2rPHUAeUPbNgTmK18FPTiZ          83
# 38   3uVPLtkmDu8pDkYEAVqbgS          83
# 41   0tbjiOUl4k492KPdWZS9sy          82
# 49   0eBXyY4SatzpE7opnzgXvz          81
# 249  0SErdEdRcVX1uJCf1eTGYH          81

# %%
import random

# %%
df_tracks1=df_tracks
df_tracks1['popularity'] = [((df_tracks1['popularity'][k]+random.randint(-2,2))%101)  for k in df_tracks.index]
df_tracks1=df_tracks1.sort_values(by='popularity', ascending=False)
df_tracks1['Date_his']='051220'
df_tracks1.head(5)
# Out:
#      artist_name                       track_name                track_id  \
# 1  Ariana Grande                        positions  35mvY5S1H3J2QZyna3TFe0
# 0       24kGoldn           Mood (feat. iann dior)  3tjFYV6RSFtuktYl3ZtYcq
# 7  Billie Eilish                   Therefore I Am  54bFM56PmE4YLRnqpW6Tha
# 8      Pop Smoke          What You Know Bout Love  1tkg4EHVoqnhR6iFEXb60y
# 4        Cardi B  WAP (feat. Megan Thee Stallion)  4Oun2ylbjFKMPTiaSbbCih
#
#    popularity Date_his
# 1         100   051220
# 0          98   051220
# 7          98   051220
# 8          97   051220
# 4          97   051220

# %%
df_tracks2=df_tracks1
df_tracks2['popularity'] = [((df_tracks2['popularity'][k]+random.randint(-2,2))%101)  for k in df_tracks.index]
df_tracks2=df_tracks2.sort_values(by='popularity', ascending=False)
df_tracks2['Date_his']='061220'
df_tracks2.head(5)
# Out:
#       artist_name                       track_name                track_id  \
# 1   Ariana Grande                        positions  35mvY5S1H3J2QZyna3TFe0
# 9      The Weeknd                  Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
# 14  Justin Bieber   Holy (feat. Chance The Rapper)  5u1n1kITHCxxp8twBcZxWy
# 16  Justin Bieber       Lonely (with benny blanco)  4y4spB9m0Q6026KfkAvy9Q
# 4         Cardi B  WAP (feat. Megan Thee Stallion)  4Oun2ylbjFKMPTiaSbbCih
#
#     popularity Date_his
# 1          100   061220
# 9           99   061220
# 14          97   061220
# 16          97   061220
# 4           96   061220

# %%
df_tracks3=df_tracks2
df_tracks3['popularity'] = [((df_tracks3['popularity'][k]+random.randint(-2,2))%101)  for k in df_tracks.index]
df_tracks3=df_tracks3.sort_values(by='popularity', ascending=False)
df_tracks3['Date_his']='071220'
df_tracks3.head(5)
# Out:
#      artist_name                       track_name                track_id  \
# 9     The Weeknd                  Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
# 199   Juice WRLD                        Righteous  5dOxHHMOFAbG3VH23t0xNm
# 19   Ritt Momney              Put Your Records On  6AGOKlMZWLCaEJGnaROtF9
# 4        Cardi B  WAP (feat. Megan Thee Stallion)  4Oun2ylbjFKMPTiaSbbCih
# 11        DaBaby     ROCKSTAR (feat. Roddy Ricch)  7ytR5pFWmSjzHJIeQkgog4
#
#      popularity Date_his
# 9            98   071220
# 199          97   071220
# 19           97   071220
# 4            97   071220
# 11           96   071220

# %%
df_tracks4=df_tracks3
df_tracks4['popularity'] = [((df_tracks4['popularity'][k]+random.randint(-2,2))%101)  for k in df_tracks.index]
df_tracks4=df_tracks4.sort_values(by='popularity', ascending=False)
df_tracks4['Date_his']='081220'
df_tracks4.head(5)
# Out:
#        artist_name                            track_name  \
# 49   Morgan Wallen                 More Than My Hometown
# 349      Pop Smoke  Hello (feat. A Boogie Wit da Hoodie)
# 36       Bad Bunny                    LA NOCHE DE ANOCHE
# 247    Don Toliver                           After Party
# 5    Ariana Grande                                 34+35
#
#                    track_id  popularity Date_his
# 49   0eBXyY4SatzpE7opnzgXvz          99   081220
# 349  2r6OAV3WsYtXuXjvJ1lIDi          97   081220
# 36   2XIc1pqjXV3Cr2BQUGNBck          96   081220
# 247  527k23H0A4Q0UJN3vGs0Da          96   081220
# 5    6Im9k8u9iIzKMrmV7BWtlF          96   081220

# %%
df_tracks5=df_tracks4
df_tracks5['popularity'] = [((df_tracks5['popularity'][k]+random.randint(-2,2))%101)  for k in df_tracks.index]
df_tracks5=df_tracks5.sort_values(by='popularity', ascending=False)
df_tracks5['Date_his']='091220'
df_tracks5.head(5)
# Out:
#        artist_name                              track_name  \
# 16   Justin Bieber              Lonely (with benny blanco)
# 42          Maluma                           Hawái - Remix
# 36       Bad Bunny                      LA NOCHE DE ANOCHE
# 76    Shawn Mendes  Monster (Shawn Mendes & Justin Bieber)
# 449      Bad Bunny                            YO VISTO ASÍ
#
#                    track_id  popularity Date_his
# 16   4y4spB9m0Q6026KfkAvy9Q          98   091220
# 42   0GzuHFG4Ql6DoyxFRnIk3F          97   091220
# 36   2XIc1pqjXV3Cr2BQUGNBck          97   091220
# 76   2Z8yfpFX0ZMavHkcIeHiO1          97   091220
# 449  5fROvzNghPid8mbKNDYvpJ          97   091220

# %%
frames = [df_tracks1,df_tracks2, df_tracks3,df_tracks4,df_tracks5]
result = pd.concat(frames)

# %%
query = result[result.track_name.eq("Real Shit (with benny blanco)")]

# %%
query
# Out:
#    artist_name                     track_name                track_id  \
# 38  Juice WRLD  Real Shit (with benny blanco)  3uVPLtkmDu8pDkYEAVqbgS
# 38  Juice WRLD  Real Shit (with benny blanco)  3uVPLtkmDu8pDkYEAVqbgS
# 38  Juice WRLD  Real Shit (with benny blanco)  3uVPLtkmDu8pDkYEAVqbgS
# 38  Juice WRLD  Real Shit (with benny blanco)  3uVPLtkmDu8pDkYEAVqbgS
# 38  Juice WRLD  Real Shit (with benny blanco)  3uVPLtkmDu8pDkYEAVqbgS
#
#     popularity Date_his
# 38          85   051220
# 38          93   061220
# 38          82   071220
# 38          95   081220
# 38          95   091220

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(query['Date_his'], query['popularity'], "-*b", markersize=8, label="nom de la courbe")

plt.xlabel("Date", fontsize=8)
plt.ylabel("Popularité", fontsize=8)

plt.legend(loc='best', fontsize=8)

plt.title("Evolution d'une chanson d'un artiste", fontsize=8)


plt.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df_tracks5['artist_name'][:5], df_tracks5['popularity'][:5], "-*b", markersize=8, label="nom de la courbe")

plt.xlabel("titre des abscisses", fontsize=8)
plt.ylabel("titre des ordonnées", fontsize=8)

plt.legend(loc='best', fontsize=8)

plt.title("titre du graphique", fontsize=8)


plt.show()

# %%
from matplotlib.pyplot import hist

hist(df_tracks3['artist_name'][:5], weights=(df_tracks3['popularity'][:5]),color = 'green')
# Out:
# (array([91.,  0.,  5.,  0.,  0., 89.,  0., 86.,  0., 95.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)
